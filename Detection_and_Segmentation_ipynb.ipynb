# %% [markdown]
# <a href="https://colab.research.google.com/github/swati-singh23/Nut--Bolt-Detection-and-Segmentation/blob/main/Detection_and_Segmentation_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision torchaudio

# %%
# !pip install torch==2.0.0+cu118 torchvision==0.15.0+cu118 torchaudio==2.0.0+cu118 -f https://download.pytorch.org/whl/cu118/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu118/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 555.5 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 55.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 70.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 8.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0+cu121
#     Uninstalling torch-2.4.0+cu121:
#       Successfully uninstalled torch-2.4.0+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.0+cu121
#     Uninstalling torchvision-0.19.0+cu121:
#       Successfully uninstalled torchvision-0.19.0+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.4.0+cu121
#     Uninstalling torchaudio-2.4.0+cu121:
# ...

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Number of GPUs:", torch.cuda.device_count())
# Out:
# PyTorch version: 2.0.0+cu118
# CUDA available: True
# Number of GPUs: 1

# %%
# !pip install torch torchvision torchaudio

# %%
# !pip install torch==2.0.0+cu118 torchvision==0.15.0+cu118 torchaudio==2.0.0+cu118 -f https://download.pytorch.org/whl/cu118/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu118/torch_stable.html
# ...

# %%
import torch
torch.__version__
# Out:
# '2.0.0+cu118'

# %%
import torch

# Check if GPU is available
if torch.cuda.is_available():
    print("GPU available: ", torch.cuda.get_device_name(0))
else:
    print("No GPU available.")
# Out:
# GPU available:  Tesla T4

# %%
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.1/871.1 kB 33.9 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.__version__
# Out:
# '8.2.82'

# %%
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# Out:
# ...
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-c3pa3jj1
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-c3pa3jj1
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 6fdee8f2727f4506cfbbe553e23b895e27956588
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for segment_anything: filename=segment_anything-1.0-py3-none-any.whl size=36590 sha256=5ef6aa527ac652dc6afbc74af22933ed7d93e8f209e10b7e94c857952975e1d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_rrai05j/wheels/10/cf/59/9ccb2f0a1bcc81d4fbd0e501680b5d088d690c6cfbc02dc99d
# Successfully built segment_anything
# ...

# %%
# !pip install ultralytics

# !pip install 'git+https://github.com/facebookresearch/segment-anything.git'

# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Out:
# ...
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-ojvpoy79
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-ojvpoy79
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 6fdee8f2727f4506cfbbe553e23b895e27956588
#   Preparing metadata (setup.py) ... done
# --2024-08-28 11:34:43--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.227.219.33, 13.227.219.70, 13.227.219.59, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.227.219.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2564550879 (2.4G) [binary/octet-stream]
# Saving to: ‘sam_vit_h_4b8939.pth’
#
# sam_vit_h_4b8939.pt 100%[===================>]   2.39G   206MB/s    in 13s
#
# ...

# %%
import ultralytics
from ultralytics import YOLO
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor
from IPython.display import display, Image
import cv2
import numpy as np
import matplotlib.pyplot as plt
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.5/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !yolo predict model=yolov8n.pt source='/content/drive/MyDrive/Detection/train/images/image_10.jpg'
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Detection/train/images/image_10.jpg: 640x640 1 fire hydrant, 2 birds, 8.1ms
# Speed: 3.2ms preprocess, 8.1ms inference, 321.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='/content/runs/detect/predict2/image_10.jpg', height=600)

# %%
model = YOLO('/content/yolov8n.pt')
results = model.predict(source='/content/runs/detect/predict2/image_10.jpg', conf=0.25)
# Out:
# image 1/1 /content/runs/detect/predict2/image_10.jpg: 640x640 1 fire hydrant, 1 bottle, 22.2ms
# Speed: 6.4ms preprocess, 22.2ms inference, 172.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
for result in results:
    boxes = result.boxes

bbox=boxes.xyxy.tolist()[0]

bbox
# Out:
# [211.4227294921875, 201.83644104003906, 406.21014404296875, 547.1207275390625]

# %%
sam_checkpoint = "/content/sam_vit_h_4b8939.pth"
model_type = "vit_h"
sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
predictor = SamPredictor(sam)

# %%
image = cv2.cvtColor(cv2.imread('/content/runs/detect/predict2/image_10.jpg'), cv2.COLOR_BGR2RGB)
predictor.set_image(image)

# %%
def show_mask(mask, ax, random_color=False):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([30/255, 144/255, 255/255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)

def show_points(coords, labels, ax, marker_size=375):
    pos_points = coords[labels==1]
    neg_points = coords[labels==0]
    ax.scatter(pos_points[:, 0], pos_points[:, 1], color='green', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)
    ax.scatter(neg_points[:, 0], neg_points[:, 1], color='red', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)

def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))

# %%
input_box = np.array(bbox)

masks, _, _ = predictor.predict(
    point_coords=None,
    point_labels=None,
    box=input_box[None, :],
    multimask_output=False,
)

plt.figure(figsize=(10, 10))
plt.imshow(image)
show_mask(masks[0], plt.gca())
show_box(input_box, plt.gca())
plt.axis('off')
plt.show()

# %%
segmentation_mask = masks[0]
binary_mask = np.where(segmentation_mask > 0.5, 1, 0)

white_background = np.ones_like(image) * 255

new_image = white_background * (1 - binary_mask[..., np.newaxis]) + image * binary_mask[..., np.newaxis]

plt.imshow(new_image.astype(np.uint8))
plt.axis('off')
plt.show()
